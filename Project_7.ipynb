# %%
import numpy as np
import pandas as pd
import datetime
import seaborn as sns
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
netflix = pd.read_csv(r'C:\Users\gixi_\Ironhack\DAFT_212\module_3\Project_week_7/imdb_processed.csv')
netflix
# Out:
#       Unnamed: 0                                              title    year  \
# 0              0                                    Dinosaur Planet  2003.0
# 1              1                                  Get Up and Dance!  1994.0
# 2              2                                              8 Man  1992.0
# 3              3                       What the #$*! Do We (K)now!?  2004.0
# 4              4  Class of Nuke 'Em High Part II: Subhumanoid Me...  1991.0
# ...          ...                                                ...     ...
# 8446        8446                                All Monsters Attack  1969.0
# 8447        8447                                       Fidel Castro  2005.0
# 8448        8448                                              Epoch  2001.0
# 8449        8449                                        The Company  2003.0
# 8450        8450                                           Predator  1987.0
#
# ...

# %%
netflix.drop('Unnamed: 0', axis=1, inplace = True)

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     8451 non-null   object
#  1   year      8451 non-null   float64
#  2   kind      8451 non-null   object
#  3   genre     8384 non-null   object
#  4   rating    8135 non-null   float64
#  5   vote      8135 non-null   float64
#  6   country   8152 non-null   object
#  7   language  8052 non-null   object
#  8   cast      8280 non-null   object
#  9   director  7140 non-null   object
#  10  composer  5722 non-null   object
#  11  writer    7204 non-null   object
#  12  runtime   6798 non-null   float64
# dtypes: float64(4), object(9)
# memory usage: 858.4+ KB

# %%
netflix = netflix.astype({"year": int})

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     8451 non-null   object
#  1   year      8451 non-null   int32
#  2   kind      8451 non-null   object
#  3   genre     8384 non-null   object
#  4   rating    8135 non-null   float64
#  5   vote      8135 non-null   float64
#  6   country   8152 non-null   object
#  7   language  8052 non-null   object
#  8   cast      8280 non-null   object
#  9   director  7140 non-null   object
#  10  composer  5722 non-null   object
#  11  writer    7204 non-null   object
#  12  runtime   6798 non-null   float64
# dtypes: float64(3), int32(1), object(9)
# memory usage: 825.4+ KB

# %%
netflix['kind'].value_counts()
# Out:
# movie             4995
# video movie       1295
# tv movie           758
# tv series          611
# episode            520
# tv mini series     239
# video game          20
# tv short            13
# Name: kind, dtype: int64

# %%
netflix['kind'] = netflix['kind'].replace(['video movie', 'tv movie', 'tv series', "tv mini series", 'episode'],['movie', 'movie', 'series', 'series', 'series'])
netflix['kind'].value_counts()
# Out:
# movie         7048
# series        1370
# video game      20
# tv short        13
# Name: kind, dtype: int64

# %%
netflix['genre'].value_counts()
# Out:
# ['Documentary']                                   452
# ['Drama']                                         451
# ['Documentary', 'Music']                          326
# ['Comedy']                                        311
# ['Drama', 'Romance']                              283
#                                                  ...
# ['Comedy', 'Drama', 'Family', 'Fantasy']            1
# ['Documentary', 'Comedy', 'Music', 'Musical']       1
# ['Animation', 'Adventure', 'Horror', 'Sci-Fi']      1
# ['Comedy', 'Musical', 'Drama', 'Family']            1
# ['Animation', 'Action', 'Comedy', 'Sci-Fi']         1
# Name: genre, Length: 1436, dtype: int64

# %%
netflix['genre'] = netflix['genre'].str.replace('[','').str.replace(']','')
netflix['genre'].value_counts()
# Out:
# <ipython-input-10-72179a59bc32>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   netflix['genre'] = netflix['genre'].str.replace('[','').str.replace(']','')
# 'Documentary'                                         452
# 'Drama'                                               451
# 'Documentary', 'Music'                                326
# 'Comedy'                                              311
# 'Drama', 'Romance'                                    283
#                                                      ...
# 'Adventure', 'Comedy', 'Mystery'                        1
# 'Documentary', 'Biography', 'Comedy', 'War'             1
# 'Comedy', 'Drama', 'Musical', 'Romance', 'Western'      1
# 'Drama', 'Sci-Fi', 'Short', 'Thriller'                  1
# 'Action', 'Comedy', 'Family', 'Fantasy', 'Sport'        1
# ...

# %%
netflix_genre = netflix.genre.str.split(',').apply(pd.Series)
netflix['genre'] = netflix_genre[0]

# %%
netflix['genre'].value_counts()
# Out:
# 'Drama'          1488
# 'Comedy'         1458
# 'Documentary'    1346
# 'Action'         1097
# 'Animation'       823
# 'Crime'           504
# 'Adventure'       344
# 'Horror'          331
# 'Biography'       238
# 'Music'           235
# 'Short'           107
# 'Family'           88
# 'Fantasy'          54
# 'Thriller'         41
# 'Sport'            41
# 'Sci-Fi'           31
# 'Mystery'          31
# 'Musical'          29
# 'Romance'          26
# 'Western'          25
# 'Reality-TV'       16
# 'Talk-Show'        11
# 'History'           8
# 'Game-Show'         7
# 'Film-Noir'         4
# 'War'               1
# Name: genre, dtype: int64

# %%
netflix['country'] = netflix['country'].str.replace('[','').str.replace(']','')
netflix['country'].value_counts()
# Out:
# <ipython-input-13-fda9e757ecfc>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   netflix['country'] = netflix['country'].str.replace('[','').str.replace(']','')
# 'United States'                             3813
# 'United Kingdom'                             742
# 'Japan'                                      573
# 'India'                                      247
# 'Hong Kong'                                  216
#                                             ...
# 'Canada', 'Hong Kong', 'United Kingdom'        1
# 'Czechia', 'United States'                     1
# 'Switzerland', 'France', 'Germany'             1
# 'United States', 'France', 'Netherlands'       1
# 'Russia', 'Kazakhstan'                         1
# Name: country, Length: 650, dtype: int64

# %%
netflix_country = netflix.country.str.split(',').apply(pd.Series)
netflix['country'] = netflix_country[0]
netflix['country'].value_counts()
# Out:
# 'United States'     4203
# 'United Kingdom'    1061
# 'Japan'              608
# 'Canada'             373
# 'France'             349
#                     ...
# 'Ecuador'              1
# 'Singapore'            1
# 'Armenia'              1
# 'Cambodia'             1
# 'Aruba'                1
# Name: country, Length: 67, dtype: int64

# %%
netflix['language'] = netflix['language'].str.replace('[','').str.replace(']','')
netflix_language = netflix.language.str.split(',').apply(pd.Series)
netflix['language'] = netflix_language[0]
netflix['language'].value_counts()
# Out:
# <ipython-input-15-459cbf69a843>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will*not* be treated as literal strings when regex=True.
#   netflix['language'] = netflix['language'].str.replace('[','').str.replace(']','')
# 'English'      5998
# 'Japanese'      510
# 'French'        305
# 'Hindi'         233
# 'Cantonese'     217
#                ...
# 'Sicilian'        1
# 'Tibetan'         1
# 'Khmer'           1
# 'Dyula'           1
# 'Bosnian'         1
# Name: language, Length: 65, dtype: int64

# %%
#Movies per country
netflix.groupby('country')['title'].count().sort_values(ascending = False)
# Out:
# country
# 'United States'              4203
# 'United Kingdom'             1061
# 'Japan'                       608
# 'Canada'                      373
# 'France'                      349
#                              ...
# 'Ecuador'                       1
# 'Greenland'                     1
# 'Palestinian Territories'       1
# 'Indonesia'                     1
# 'Côte d’Ivoire'                 1
# Name: title, Length: 67, dtype: int64

# %%
#Number of movies per year
netflix.groupby('year')['title'].count()
# Out:
# year
# 1905      5
# 1910      1
# 1913      1
# 1914      1
# 1916      1
#        ...
# 2001    623
# 2002    643
# 2003    683
# 2004    663
# 2005    301
# Name: title, Length: 91, dtype: int64

# %%
#The most popular genre per country
netflix.groupby(['country','genre'])['genre'].count().sort_values().groupby(level=0).tail(1).sort_values(ascending = False)
# Out:
# country           genre
# 'United States'   'Documentary'    960
# 'Japan'           'Animation'      385
# 'United Kingdom'  'Drama'          210
# 'Hong Kong'       'Action'         186
# 'France'          'Drama'          126
#                                   ...
# 'Venezuela'       'Comedy'           1
# 'Chile'           'Action'           1
# 'Colombia'        'Crime'            1
# 'Singapore'       'Comedy'           1
# 'Peru'            'Action'           1
# Name: genre, Length: 67, dtype: int64

# %%
#Movies per country
netflix.groupby(['year','genre'])['genre'].count().sort_values().groupby(level=0).tail(1).sort_values(ascending = False)
# Out:
# year  genre
# 2004  'Documentary'    190
# 2003  'Documentary'    155
# 2002  'Documentary'    144
# 2001  'Documentary'    120
# 2000  'Drama'          109
#                       ...
# 1919  'Drama'            1
# 1913  'Short'            1
# 1910  'Documentary'      1
# 1924  'Adventure'        1
# 1925  'Drama'            1
# Name: genre, Length: 91, dtype: int64

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 13 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     8451 non-null   object
#  1   year      8451 non-null   int32
#  2   kind      8451 non-null   object
#  3   genre     8384 non-null   object
#  4   rating    8135 non-null   float64
#  5   vote      8135 non-null   float64
#  6   country   8152 non-null   object
#  7   language  8052 non-null   object
#  8   cast      8280 non-null   object
#  9   director  7140 non-null   object
#  10  composer  5722 non-null   object
#  11  writer    7204 non-null   object
#  12  runtime   6798 non-null   float64
# dtypes: float64(3), int32(1), object(9)
# memory usage: 825.4+ KB

# %%
netflix.genre.isna().sum()
# Out:
# 67

# %%
netflix.drop('composer',axis = 1, inplace = True)

# %%
netflix.drop('writer',axis = 1, inplace = True)

# %%
netflix.drop('runtime',axis = 1, inplace = True)

# %%
netflix.drop('director',axis = 1, inplace = True)

# %%
netflix.drop('cast',axis = 1, inplace = True)

# %%
countries_to_keep = netflix['country'].value_counts().sort_values(ascending= False)[7:].index
netflix['country'].loc[netflix['country'].isin(countries_to_keep)] = "Other country"
netflix['country'].value_counts()
# Out:
# C:\Users\gixi_\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# 'United States'     4203
# 'United Kingdom'    1061
# Other country       1039
# 'Japan'              608
# 'Canada'             373
# 'France'             349
# 'Hong Kong'          265
# 'India'              254
# Name: country, dtype: int64

# %%
languages_to_keep = netflix['language'].value_counts().sort_values(ascending= False)[5:].index
netflix['language'].loc[netflix['language'].isin(languages_to_keep)] = "Other language"
netflix['language'].value_counts()
# Out:
# 'English'         5998
# Other language     789
# 'Japanese'         510
# 'French'           305
# 'Hindi'            233
# 'Cantonese'        217
# Name: language, dtype: int64

# %%
netflix
# Out:
#                                                   title  year    kind  \
# 0                                       Dinosaur Planet  2003  series
# 1                                     Get Up and Dance!  1994   movie
# 2                                                 8 Man  1992   movie
# 3                          What the #$*! Do We (K)now!?  2004   movie
# 4     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991   movie
# ...                                                 ...   ...     ...
# 8446                                All Monsters Attack  1969   movie
# 8447                                       Fidel Castro  2005  series
# 8448                                              Epoch  2001   movie
# 8449                                        The Company  2003   movie
# 8450                                           Predator  1987   movie
#
#               genre  rating      vote          country    language
# ...

# %%
netflix['genre'] = netflix['genre'].str.replace("'",'')

# %%
netflix['country'] = netflix['country'].str.replace("'",'')
netflix['language'] = netflix['language'].str.replace("'",'')

# %%
netflix
# Out:
#                                                   title  year    kind  \
# 0                                       Dinosaur Planet  2003  series
# 1                                     Get Up and Dance!  1994   movie
# 2                                                 8 Man  1992   movie
# 3                          What the #$*! Do We (K)now!?  2004   movie
# 4     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991   movie
# ...                                                 ...   ...     ...
# 8446                                All Monsters Attack  1969   movie
# 8447                                       Fidel Castro  2005  series
# 8448                                              Epoch  2001   movie
# 8449                                        The Company  2003   movie
# 8450                                           Predator  1987   movie
#
#             genre  rating      vote        country  language
# 0     Documentary     7.7     474.0  United States   English
# ...

# %%
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8451 entries, 0 to 8450
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     8451 non-null   object
#  1   year      8451 non-null   int32
#  2   kind      8451 non-null   object
#  3   genre     8384 non-null   object
#  4   rating    8135 non-null   float64
#  5   vote      8135 non-null   float64
#  6   country   8152 non-null   object
#  7   language  8052 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 495.3+ KB

# %%
netflix['country'].fillna('Other country',inplace=True)
netflix['language'].fillna('Other language',inplace=True)

# %%
netflix.loc[netflix['rating'].isna()==True]
netflix.dropna(subset=['rating', 'vote','genre'], inplace = True)
netflix.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8089 entries, 0 to 8450
# Data columns (total 8 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   title     8089 non-null   object
#  1   year      8089 non-null   int32
#  2   kind      8089 non-null   object
#  3   genre     8089 non-null   object
#  4   rating    8089 non-null   float64
#  5   vote      8089 non-null   float64
#  6   country   8089 non-null   object
#  7   language  8089 non-null   object
# dtypes: float64(2), int32(1), object(5)
# memory usage: 537.2+ KB

# %%
netflix["rating"] = pd.cut(netflix["rating"],5, precision=0, labels=[1,2,3,4,5])
netflix["rating"]
netflix
# Out:
#                                                   title  year    kind  \
# 0                                       Dinosaur Planet  2003  series
# 1                                     Get Up and Dance!  1994   movie
# 2                                                 8 Man  1992   movie
# 3                          What the #$*! Do We (K)now!?  2004   movie
# 4     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991   movie
# ...                                                 ...   ...     ...
# 8446                                All Monsters Attack  1969   movie
# 8447                                       Fidel Castro  2005  series
# 8448                                              Epoch  2001   movie
# 8449                                        The Company  2003   movie
# 8450                                           Predator  1987   movie
#
#             genre rating      vote        country  language
# 0     Documentary      4     474.0  United States   English
# ...

# %%
netflix
# Out:
#                                                   title  year    kind  \
# 0                                       Dinosaur Planet  2003  series
# 1                                     Get Up and Dance!  1994   movie
# 2                                                 8 Man  1992   movie
# 3                          What the #$*! Do We (K)now!?  2004   movie
# 4     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991   movie
# ...                                                 ...   ...     ...
# 8446                                All Monsters Attack  1969   movie
# 8447                                       Fidel Castro  2005  series
# 8448                                              Epoch  2001   movie
# 8449                                        The Company  2003   movie
# 8450                                           Predator  1987   movie
#
#             genre rating      vote        country  language
# 0     Documentary      4     474.0  United States   English
# ...

# %%
netflix_dummies = pd.get_dummies(netflix, columns=['kind','genre', 'country', 'language'], drop_first=True)
netflix_dummies
# Out:
#                                                   title  year rating  \
# 0                                       Dinosaur Planet  2003      4
# 1                                     Get Up and Dance!  1994      5
# 2                                                 8 Man  1992      3
# 3                          What the #$*! Do We (K)now!?  2004      3
# 4     Class of Nuke 'Em High Part II: Subhumanoid Me...  1991      2
# ...                                                 ...   ...    ...
# 8446                                All Monsters Attack  1969      2
# 8447                                       Fidel Castro  2005      4
# 8448                                              Epoch  2001      3
# 8449                                        The Company  2003      3
# 8450                                           Predator  1987      4
#
#           vote  kind_series  kind_tv short  kind_video game  genre_Adventure  \
# ...

# %%
netflix_dummies.drop('title', axis = 1, inplace = True)

# %%
netflix_dummies.columns
netflix_dummies.drop(['language_French',
       'language_Hindi', 'language_Japanese', 'language_Other language'], axis = 1, inplace = True)

# %% [markdown]
# - PassiveAggressiveClassifier
# - SGDClassifier
# - ComplementNB
# - RandomForestClassifier

# %%
x = netflix_dummies.drop('rating', axis = 1)
y = netflix_dummies['rating']

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %%
def generate_results(model, predictions, name):
    cl_rep = classification_report(y_test, predictions)
    print("\nThe classification report for " + name + " is:", cl_rep, sep = "\n")
    cm_model = confusion_matrix(y_test, predictions)
    plt.figure(figsize = (8, 6))
    sns.heatmap(cm_model, annot = True, cmap = 'Blues', annot_kws = {'size': 15}, square = True)
    plt.title('Confusion Matrix for ' + name, size = 15)
    plt.xticks(size = 15)
    plt.yticks(size = 15)
    plt.show()
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
y_pred = rfc.predict(x_test)
acc_rfc = rfc.score(x_test, y_test)
print('The accuracy of the Random Forest Classifier is:', acc_rfc * 100, '%')
generate_results(rfc, y_pred, 'Random Forest Classifier')
# Out:
# The accuracy of the Random Forest Classifier is: 60.44499381953028 %
#
# The classification report for Random Forest Classifier is:
#               precision    recall  f1-score   support
#
#            1       0.25      0.17      0.20        30
#            2       0.41      0.33      0.37       118
#            3       0.53      0.51      0.52       412
#            4       0.67      0.75      0.71       826
#            5       0.57      0.44      0.49       232
#
#     accuracy                           0.60      1618
#    macro avg       0.49      0.44      0.46      1618
# weighted avg       0.59      0.60      0.60      1618

# %%
## ComplementNB
from sklearn.naive_bayes import ComplementNB
clf = ComplementNB()
clf.fit(x, y)
y_pred = clf.predict(x_test)
acc_clf = clf.score(x_test, y_test)
print('The accuracy of the  ComplementNB is:', acc_clf * 100, '%')
generate_results(rfc, y_pred, 'ComplementNB')
# Out:
# The accuracy of the  ComplementNB is: 26.57601977750309 %
#
# The classification report for ComplementNB is:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        30
#            2       0.00      0.00      0.00       118
#            3       0.27      0.90      0.41       412
#            4       0.00      0.00      0.00       826
#            5       0.25      0.26      0.26       232
#
#     accuracy                           0.27      1618
#    macro avg       0.10      0.23      0.13      1618
# weighted avg       0.10      0.27      0.14      1618
# C:\Users\gixi_\anaconda3\lib\site-packages\sklearn\metrics\_classification.py:1245: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# ...

# %%
#SGDClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline

# Always scale the input. The most convenient way is to use a pipeline.
clf1 = make_pipeline(StandardScaler(),
                     SGDClassifier(max_iter=1000, tol=1e-3))
clf1.fit(x, y)
y_pred = clf1.predict(x_test)
acc_clf = clf1.score(x_test, y_test)
print('The accuracy of the  ComplementNB is:', acc_clf * 100, '%')
generate_results(rfc, y_pred, 'SGDClassifier')
# Out:
# The accuracy of the  ComplementNB is: 52.843016069221264 %
#
# The classification report for SGDClassifier is:
#               precision    recall  f1-score   support
#
#            1       0.00      0.00      0.00        30
#            2       0.39      0.14      0.20       118
#            3       0.40      0.23      0.29       412
#            4       0.57      0.83      0.68       826
#            5       0.44      0.25      0.32       232
#
#     accuracy                           0.53      1618
#    macro avg       0.36      0.29      0.30      1618
# weighted avg       0.48      0.53      0.48      1618

# %%
from sklearn.linear_model import PassiveAggressiveClassifier
from sklearn.datasets import make_classification
from sklearn.metrics import classification_report, accuracy_score
from sklearn.metrics import precision_score
# Creating model
model_passagg = PassiveAggressiveClassifier(C = 0.5, random_state = 5)
# Fitting model
model_passagg.fit(x_train, y_train)
# Making prediction on test set
test_pred = model_passagg.predict(x_test)
# Model evaluation
print(f"Test Set Accuracy : {accuracy_score(y_test, test_pred) * 100} %\n\n")
print(f"Classification Report : \n\n{classification_report(y_test, test_pred,zero_division=1)}")
# Out:
# Test Set Accuracy : 29.72805933250927 %
#
#
# Classification Report :
#
#               precision    recall  f1-score   support
#
#            1       1.00      0.00      0.00        30
#            2       1.00      0.00      0.00       118
#            3       0.21      0.25      0.23       412
#            4       0.46      0.43      0.45       826
#            5       0.06      0.10      0.08       232
#
#     accuracy                           0.30      1618
#    macro avg       0.55      0.16      0.15      1618
# weighted avg       0.39      0.30      0.30      1618
